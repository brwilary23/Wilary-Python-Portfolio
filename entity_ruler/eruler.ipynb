# %% [markdown]
# ## 1. Setup Environment

# %%
# import required data sets

#import pandas
import pandas as pd
#import spacy and displacy from spacy
import spacy
from spacy import displacy
#set up nlp
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## 2. Load the Dataset

# %%
#read stock set
stock_set = pd.read_csv("stocks-1.tsv",sep='\t')

#put stock set in a data frame
df_stock = pd.DataFrame(stock_set)
display(df_stock)
# Out:
#      Symbol              CompanyName                          Industry  \
# 0         A     Agilent Technologies    Life Sciences Tools & Services
# 1        AA                    Alcoa                   Metals & Mining
# 2       AAC         Ares Acquisition                   Shell Companies
# 3      AACG    ATA Creativity Global     Diversified Consumer Services
# 4      AADI          Aadi Bioscience                   Pharmaceuticals
# ...     ...                      ...                               ...
# 5874   ZWRK       Z-Work Acquisition                   Shell Companies
# 5875     ZY                 Zymergen                         Chemicals
# 5876   ZYME                Zymeworks                     Biotechnology
# 5877   ZYNE  Zynerba Pharmaceuticals                   Pharmaceuticals
# 5878   ZYXI                    Zynex  Health Care Equipment & Supplies
#
#      MarketCap
# 0       53.65B
# 1        9.25B
# 2        1.22B
# 3       90.35M
# 4      104.85M
# ...        ...
# 5874   278.88M
# 5875     1.31B
# 5876     1.50B
# 5877   184.39M
# 5878   438.33M
#
# [5879 rows x 4 columns]

# %% [markdown]
# ## 3. Extract Data for Patterns

# %%
# create empty lists
symbol = []
company_name = []

#goes through the dataframe and relabel it to label and pattern for symbol
for x in df_stock["Symbol"]:
    symbol.append({"label":"symbol", "pattern":x})

#goes through the dataframe and relabel it to label and pattern for company name
for x in df_stock["CompanyName"]:
    company_name.append({"label":"companyname", "pattern":x})

#print out to see
print(symbol)
print(company_name)
# Out:
# [{'label': 'symbol', 'pattern': 'A'}, {'label': 'symbol', 'pattern': 'AA'}, {'label': 'symbol', 'pattern': 'AAC'}, {'label': 'symbol', 'pattern': 'AACG'}, {'label': 'symbol', 'pattern': 'AADI'}, {'label': 'symbol', 'pattern': 'AAIC'}, {'label': 'symbol', 'pattern': 'AAL'}, {'label': 'symbol', 'pattern': 'AAMC'}, {'label': 'symbol', 'pattern': 'AAME'}, {'label': 'symbol', 'pattern': 'AAN'}, {'label': 'symbol', 'pattern': 'AAOI'}, {'label': 'symbol', 'pattern': 'AAON'}, {'label': 'symbol', 'pattern': 'AAP'}, {'label': 'symbol', 'pattern': 'AAPL'}, {'label': 'symbol', 'pattern': 'AAQC'}, {'label': 'symbol', 'pattern': 'AAT'}, {'label': 'symbol', 'pattern': 'AATC'}, {'label': 'symbol', 'pattern': 'AAU'}, {'label': 'symbol', 'pattern': 'AAWW'}, {'label': 'symbol', 'pattern': 'AB'}, {'label': 'symbol', 'pattern': 'ABB'}, {'label': 'symbol', 'pattern': 'ABBV'}, {'label': 'symbol', 'pattern': 'ABC'}, {'label': 'symbol', 'pattern': 'ABCB'}, {'label': 'symbol', 'pattern': 'ABCL'}, {'label': 'symbol', 'pattern': 'ABCM'}, {'label': 'symbol', 'pattern': 'ABEO'}, {'label': 'symbol', 'pattern': 'ABEV'}, {'label': 'symbol', 'pattern': 'ABG'}, {'label': 'symbol', 'pattern': 'ABGI'}, {'label': 'symbol', 'pattern': 'ABIO'}, {'label': 'symbol', 'pattern': 'ABM'}, {'label': 'symbol', 'pattern': 'ABMD'}, {'label': 'symbol', 'pattern': 'ABNB'}, {'label': 'symbol', 'pattern': 'ABOS'}, {'label': 'symbol', 'pattern': 'ABR'}, {'label': 'symbol', 'pattern': 'ABSI'}, {'label': 'symbol', 'pattern': 'ABST'}, {'label': 'symbol', 'pattern': 'ABT'}, {'label': 'symbol', 'pattern': 'ABTX'}, {'label': 'symbol', 'pattern': 'ABUS'}, {'label': 'symbol', 'pattern': 'ABVC'}, {'label': 'symbol', 'pattern': 'AC'}, {'label': 'symbol', 'pattern': 'ACA'}, {'label': 'symbol', 'pattern': 'ACAD'}, {'label': 'symbol', 'pattern': 'ACAH'}, {'label': 'symbol', 'pattern': 'ACB'}, {'label': 'symbol', 'pattern': 'ACBA'}, {'label': 'symbol', 'pattern': 'ACBI'}, {'label': 'symbol', 'pattern': 'ACC'}, {'label': 'symbol', 'pattern': 'ACCD'}, {'label': 'symbol', 'pattern': 'ACCO'}, {'label': 'symbol', 'pattern': 'ACEL'}, {'label': 'symbol', 'pattern': 'ACER'}, {'label': 'symbol', 'pattern': 'ACET'}, {'label': 'symbol', 'pattern': 'ACEV'}, {'label': 'symbol', 'pattern': 'ACGL'}, {'label': 'symbol', 'pattern': 'ACH'}, {'label': 'symbol', 'pattern': 'ACHC'}, {'label': 'symbol', 'pattern': 'ACHL'}, {'label': 'symbol', 'pattern': 'ACHV'}, {'label': 'symbol', 'pattern': 'ACI'}, {'label': 'symbol', 'pattern': 'ACIC'}, {'label': 'symbol', 'pattern': 'ACII'}, {'label': 'symbol', 'pattern': 'ACIU'}, {'label': 'symbol', 'pattern': 'ACIW'}, {'label': 'symbol', 'pattern': 'ACKIT'}, {'label': 'symbol', 'pattern': 'ACLS'}, {'label': 'symbol', 'pattern': 'ACM'}, {'label': 'symbol', 'pattern': 'ACMR'}, {'label': 'symbol', 'pattern': 'ACN'}, {'label': 'symbol', 'pattern': 'ACNB'}, {'label': 'symbol', 'pattern': 'ACOR'}, {'label': 'symbol', 'pattern': 'ACQR'}, {'label': 'symbol', 'pattern': 'ACR'}, {'label': 'symbol', 'pattern': 'ACRE'}, {'label': 'symbol', 'pattern': 'ACRO'}, {'label': 'symbol', 'pattern': 'ACRS'}, {'label': 'symbol', 'pattern': 'ACRX'}, {'label': 'symbol', 'pattern': 'ACST'}, {'label': 'symbol', 'pattern': 'ACTD'}, {'label': 'symbol', 'pattern': 'ACTG'}, {'label': 'symbol', 'pattern': 'ACU'}, {'label': 'symbol', 'pattern': 'ACVA'}, {'label': 'symbol', 'pattern': 'ACXP'}, {'label': 'symbol', 'pattern': 'ACY'}, {'label': 'symbol', 'pattern': 'ADAG'}, {'label': 'symbol', 'pattern': 'ADAP'}, {'label': 'symbol', 'pattern': 'ADBE'}, {'label': 'symbol', 'pattern': 'ADC'}, {'label': 'symbol', 'pattern': 'ADCT'}, {'label': 'symbol', 'pattern': 'ADER'}, {'label': 'symbol', 'pattern': 'ADES'}, {'label': 'symbol', 'pattern': 'ADEX'}, {'label': 'symbol', 'pattern': 'ADF'}, {'label': 'symbol', 'pattern': 'ADGI'}, {'label': 'symbol', 'pattern': 'ADI'}, {'label': 'symbol', 'pattern': 'ADIL'}, {'label': 'symbol', 'pattern': 'ADM'}, {'label': 'symbol', 'pattern': 'ADMA'}, {'label': 'symbol', 'pattern': 'A ...
# [{'label': 'companyname', 'pattern': 'Agilent Technologies'}, {'label': 'companyname', 'pattern': 'Alcoa'}, {'label': 'companyname', 'pattern': 'Ares Acquisition'}, {'label': 'companyname', 'pattern': 'ATA Creativity Global'}, {'label': 'companyname', 'pattern': 'Aadi Bioscience'}, {'label': 'companyname', 'pattern': 'Arlington Asset Investment'}, {'label': 'companyname', 'pattern': 'American Airlines'}, {'label': 'companyname', 'pattern': 'Altisource Asset Management'}, {'label': 'companyname', 'pattern': 'Atlantic American'}, {'label': 'companyname', 'pattern': "The Aaron's Company"}, {'label': 'companyname', 'pattern': 'Applied Optoelectronics'}, {'label': 'companyname', 'pattern': 'AAON, Inc.'}, {'label': 'companyname', 'pattern': 'Advance Auto Parts'}, {'label': 'companyname', 'pattern': 'Apple'}, {'label': 'companyname', 'pattern': 'Accelerate Acquisition'}, {'label': 'companyname', 'pattern': 'American Assets Trust'}, {'label': 'companyname', 'pattern': 'Autoscope Technologies'}, {'label': 'companyname', 'pattern': 'Almaden Minerals'}, {'label': 'companyname', 'pattern': 'Atlas Air Worldwide Holdings'}, {'label': 'companyname', 'pattern': 'AllianceBernstein'}, {'label': 'companyname', 'pattern': 'ABB Ltd.'}, {'label': 'companyname', 'pattern': 'AbbVie'}, {'label': 'companyname', 'pattern': 'AmerisourceBergen'}, {'label': 'companyname', 'pattern': 'Ameris Bancorp'}, {'label': 'companyname', 'pattern': 'AbCellera Biologics'}, {'label': 'companyname', 'pattern': 'Abcam PLC'}, {'label': 'companyname', 'pattern': 'Abeona Therapeutics'}, {'label': 'companyname', 'pattern': 'Ambev'}, {'label': 'companyname', 'pattern': 'Asbury Automotive Group'}, {'label': 'companyname', 'pattern': 'ABG Acquisition I'}, {'label': 'companyname', 'pattern': 'ARCA biopharma'}, {'label': 'companyname', 'pattern': 'ABM Industries'}, {'label': 'companyname', 'pattern': 'Abiomed'}, {'label': 'companyname', 'pattern': 'Airbnb'}, {'label': 'companyname', 'pattern': 'Acumen Pharmaceuticals'}, {'label': 'companyname', 'pattern': 'Arbor Realty Trust'}, {'label': 'companyname', 'pattern': 'Absci'}, {'label': 'companyname', 'pattern': 'Absolute Software'}, {'label': 'companyname', 'pattern': 'Abbott Laboratories'}, {'label': 'companyname', 'pattern': 'Allegiance Bancshares'}, {'label': 'companyname', 'pattern': 'Arbutus Biopharma'}, {'label': 'companyname', 'pattern': 'ABVC BioPharma'}, {'label': 'companyname', 'pattern': 'Associated Capital Group'}, {'label': 'companyname', 'pattern': 'Arcosa'}, {'label': 'companyname', 'pattern': 'ACADIA Pharmaceuticals'}, {'label': 'companyname', 'pattern': 'Atlantic Coastal Acquisition'}, {'label': 'companyname', 'pattern': 'Aurora Cannabis'}, {'label': 'companyname', 'pattern': 'Ace Global Business Acquisition'}, {'label': 'companyname', 'pattern': 'Atlantic Capital Bancshares'}, {'label': 'companyname', 'pattern': 'American Campus Communities'}, {'label': 'companyname', 'pattern': 'Accolade'}, {'label': 'companyname', 'pattern': 'ACCO Brands'}, {'label': 'companyname', 'pattern': 'Accel Entertainment'}, {'label': 'companyname', 'pattern': 'Acer Therapeutics'}, {'label': 'companyname', 'pattern': 'Adicet Bio'}, {'label': 'companyname', 'pattern': 'ACE Convergence Acquisition'}, {'label': 'companyname', 'pattern': 'Arch Capital Group'}, {'label': 'companyname', 'pattern': 'Aluminum Corporation of China'}, {'label': 'companyname', 'pattern': 'Acadia Healthcare Company'}, {'label': 'companyname', 'pattern': 'Achilles Therapeutics'}, {'label': 'companyname', 'pattern': 'Achieve Life Sciences'}, {'label': 'companyname', 'pattern': 'Albertsons Companies'}, {'label': 'companyname', 'pattern': 'Atlas Crest Investment'}, {'label': 'companyname', 'pattern': 'Atlas Crest Investment II'}, {'label': 'companyname', 'pattern': 'AC Immune'}, {'label': 'companyname', 'pattern': 'ACI Worldwide'}, {'label': 'companyname', 'pattern': 'Ackrell SPAC Partners I'}, {'label': 'companyname', 'pattern': 'Axcelis Technologies'}, {'label': 'compan ...

# %% [markdown]
# ## 4. Create an EntityRuler

# %%
#make sure there isn't an eror in putting in ruler
if "ner" in nlp.pipe_names:
    # If entity_ruler already exists, simply add patterns to it.
    try:
        ruler = nlp.get_pipe("entity_ruler")
    except Exception:
        ruler = nlp.add_pipe("entity_ruler", before="ner")
    ruler.add_patterns(symbol)
else:
    # If the NER component does not exist, add both the EntityRuler and the NER component.
    ruler = nlp.add_pipe("entity_ruler")
    ruler.add_patterns(symbol)
    ner = nlp.add_pipe("ner")

# %%
# check pipe names
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'entity_ruler',
#  'ner']

# %% [markdown]
# ## 5. Test the EntityRuler

# %%
#tests correct implementation with doc1
doc1 = nlp("Helmerich & Payne (HP) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Energy Equipment & Services sector. In contrast, Check-Cap (CHEK) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions. Meanwhile, Vallon Pharmaceuticals (VLON) gained 0.8% after strong quarterly earnings, outperforming its peers in the Biotechnology space. Sequans Communications (SQNS) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Semiconductors & Semiconductor Equipment industry.")
displacy.render(doc1, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Helmerich &amp; Payne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) saw its stock rise by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , fueled by optimistic forecasts in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Energy Equipment &amp; Services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sector. In contrast,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Check-Cap
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHEK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) faced a decline of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  following its announcement of increased costs related to supply chain disruptions. Meanwhile,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vallon Pharmaceuticals
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VLON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) gained
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  after strong
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  earnings, outperforming its peers in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biotechnology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  space.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sequans Communications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQNS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) also recorded a modest increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , reflecting investors' confidence in its ability to navigate challenges in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Semiconductors &amp; Semiconductor Equipment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  industry.</div></span>

# %%
#tests correct implementation with doc2
doc2 = nlp("Aemetis (AMTX) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Oil, Gas & Consumable Fuels sector. In contrast, Ferro Corporation (FOE) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions. Meanwhile, RingCentral (RNG) gained 0.8% after strong quarterly earnings, outperforming its peers in the Software space. ACI Worldwide (ACIW) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Software industry.")
displacy.render(doc2, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aemetis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMTX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) saw its stock rise by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , fueled by optimistic forecasts in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Oil, Gas &amp; Consumable Fuels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sector. In contrast,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ferro Corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FOE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) faced a decline of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  following its announcement of increased costs related to supply chain disruptions. Meanwhile,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RingCentral
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RNG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) gained
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  after strong
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  earnings, outperforming its peers in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  space.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACI Worldwide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACIW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) also recorded a modest increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , reflecting investors' confidence in its ability to navigate challenges in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  industry.</div></span>

# %%
#tests correct implementation with doc3
doc3= nlp("On a mixed trading day, Par Pacific Holdings (PARR) saw its stock rise by 1.5%, fueled by optimistic forecasts in the Oil, Gas & Consumable Fuels sector. In contrast, Nano Dimension (NNDM) faced a decline of 2.3% following its announcement of increased costs related to supply chain disruptions.Meanwhile, Beyond Meat (BYND) gained 0.8% after strong quarterly earnings, outperforming its peers in the Food Products space. Apollo Investment (AINV) also recorded a modest increase of 0.5%, reflecting investors' confidence in its ability to navigate challenges in the Capital Markets industry.")
displacy.render(doc3, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On a mixed trading day,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Par Pacific Holdings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PARR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) saw its stock rise by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , fueled by optimistic forecasts in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Oil, Gas &amp; Consumable Fuels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sector. In contrast,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nano Dimension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NNDM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) faced a decline of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  following its announcement of increased costs related to supply chain disruptions.Meanwhile,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beyond Meat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BYND
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) gained
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  after strong
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  earnings, outperforming its peers in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Food Products
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  space.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apollo Investment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">companyname</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AINV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">symbol</span>
# </mark>
# ) also recorded a modest increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , reflecting investors' confidence in its ability to navigate challenges in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Capital Markets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  industry.</div></span>
